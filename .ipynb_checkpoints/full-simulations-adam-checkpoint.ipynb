# %% [markdown]
# # SVGD for quantum tomography using PyMC
#
# ## This notebook is a tutorial of the docuemnt
#
# In this notebook we are going to use PyMC in order to estimate random quantum states.

# %%
import pymc3 as pm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import arviz as az
import time
print(f"Running on PyMC3 v{pm.__version__}")
# Out:
# Running on PyMC3 v3.11.2

# %% [markdown]
# In this notebook,
#
# given $$\vec{x}=(x_0,x_1,x_2,x_3),$$
#
# where every $x_i$ is normal random variable. We want to get
#
# $$\tilde{\rho}= \frac{1}{||\tilde{\rho}||}\begin{bmatrix} x_0^2 & x_0(x_1-ix_2) \\
# x_0 (x_1+ix_2)& x_1^2+x_2^2+x_3^2 \end{bmatrix}. $$
#
# We will have a sample of $\tilde{\rho}$  becuase x_i's are normal random variables.
#
# $\tilde{\rho}$ comes from
#
# $$X= \begin{bmatrix} x_0 & 0 \\
# x_1+ix_2 & x_3 \end{bmatrix},$$
# thus,
#
# $$\tilde{\rho}=X X^\dagger $$

# %%
## fucntion 
## We define the fucntion that will convert the vector x into a density matrix

## the input is the x0, x1,x2,x3 from the Cholesky decompostion
def vec2rho(x): 
    '''Generate a matrix using the Cholesky decomposition.  '''
    ##INPUT
    #x(list): list of 4 random numbers coming from a normal distribution
    #OUTPUT
    #
    d = int(np.sqrt(x.shape[0])) 
    X = 1j*np.zeros([d,d]) 
    # the first d-1 entries are the diagonal of X (the dth entry is fixed  by normalisation) 
    # the first d entries are the diagonal of X 
    np.fill_diagonal(X,x[:d]) 
    # indices of the upper triangle of d x d matrix 
    idu = np.triu_indices(d,1) 
    # take the next d (d-1)/2 entries and make them the real part of the upper triangle 
    X[idu] = x[d:d+int(d*(d-1)/2)] 
    # take the final d (d-1)/2 entrie
    # take the final d (d-1)/2 entries and make them the imaginary part of the upper triangle 
    X[idu] += -1j * x[-int(d*(d-1)/2):]  ## modified in order to get our tilde rho
    # now do the X^dag X thing 
    rho = X.T.conj() @ X 
    #rho = X@ X.T.conj() 
    return rho/np.trace(rho)

# %%
##testing function cell
x = np.array([1,2,3,4])
vec2rho(x)
# Out:
# array([[0.03333333+0.j        , 0.1       -0.13333333j],
#        [0.1       +0.13333333j, 0.96666667+0.j        ]])

# %%
### fidelity of between mixed states 
# F(rho1, rho2) = (tr(sqrt( sqrt(rho1) rho2 sqrt(rho1))  )**2, 
#where
# sqrt A = 1/tau (A +det (A)**(0.5) * Identity) 
#and
# tau = (Tr A + 2 det(A)**(0.5) )**(0.5)

def sqrtmatrix(rho1):
    '''Generates the square root of a matrix 2x2'''
    #INPUT
    #rho1(numpy matrix 2x2 )
    #OUTPUT
    # (numpy matrix 2x2): the square root of rho1
    tracerho1 = np.trace(rho1)
    detrho1 = np.linalg.det(rho1)
    tau = (tracerho1+2.0*detrho1**(0.5))**0.5
    identity = np.array([[1.0,0.0],[0.0,1.0]])
    return 1/tau*(rho1+detrho1**(0.5)*identity)

def fidelity(rho1, rho2):
    '''Gives the fidelity of two density matrices'''
    #INPUT
    #rho1(numpy matrix 2x2 ): density matrix 
    #rho2(numpy matrix 2x2 ): density matrix
    #OUTPUT
    # (float): fidelity between rho1 and rho2
    sqrt1 = sqrtmatrix(rho1)
    aux = np.matmul(sqrt1,rho2)
    aux2 = np.matmul(aux,sqrt1)
    bigsqrt=sqrtmatrix(aux2)

    return ((np.trace(bigsqrt))**2).real

# %%
## function that uses PyMC3  and estimates a random quantum state using SVGD and SMC 
def svgd_prestates(N=1000,z_observed=700,x_observed=200,y_observed=400,
                   svgd_num_part = 1000,svgd_lear_rate = 0.01,svgd_iter = 200):
  ''' Generate the posteior of the   the estimated xi with i\in{0,1,2,3} with svgd approximation  '''

  with pm.Model() as Binconstrain:
    #start with xi normal random variables
    x0 = pm.Normal("x0",mu = 0.0, sigma = 1.0)
    x1 = pm.Normal("x1",mu = 0.0, sigma = 1.0)
    x2 = pm.Normal("x2",mu = 0.0, sigma = 1.0)
    x3 = pm.Normal("x3",mu = 0.0, sigma = 1.0)

    #define the probabilities
    pz0 = (1+1/(x0**2+x1**2+x2**2+x3**2)*(x0**2-(x1**2+x2**2+x3**2)))/2
    px0 = (1+1/(x0**2+x1**2+x2**2+x3**2)*2*x0*x1)/2
    py0 = (1+1/(x0**2+x1**2+x2**2+x3**2)*2*x0*x2)/2
    
    #
    pz = pm.Deterministic('pz',pz0)
    px = pm.Deterministic('px',px0)
    py = pm.Deterministic('py',py0)

    zxy = pm.Binomial("z",n=N,p=pz,observed=z_observed)*pm.Binomial(
        "x",n=N,p=px,observed=x_observed)*pm.Binomial("y",n=N,p=py,observed=y_observed)

    ##SVGD approx
    svgd_approx = pm.fit(svgd_iter,method="svgd",inf_kwargs=dict(
        n_particles=svgd_num_part),obj_optimizer = pm.adam(learning_rate=svgd_lear_rate),progressbar=False)
    
    #comparison with SMS
    sms = pm.sample_smc(2000,parallel=True,cores=4)
    #az_trace = az.from_pymc3(sms)
    
    
    return svgd_approx, sms

# %%
## from svgd_fit to a density matrix
def svgd_rho_mean(svgd_state, n_samples = 2000):
    '''This function will generate an estimated quantum state using SVGD'''
    ### INPUT
    # svgd_state(PyMC 3 approximation): appoximation of a variational posterior given by SVGD
    #n_samples(int): Draw samples from variational posterior.
    fullsamples = svgd_state.sample(n_samples)
    x0_matrix = fullsamples['x0'] # from the posterior we take the estimated prior ['x0']
    x1_matrix = fullsamples['x1'] # from the posterior we take the estimated prior ['x1']
    x2_matrix = fullsamples['x2'] # from the posterior we take the estimated prior ['x2']
    x3_matrix = fullsamples['x3'] # from the posterior we take the estimated prior ['x3']
    rho = 1j * np.zeros([2,2])
    for i in range(n_samples):
        vec = np.array([x0_matrix[i],x3_matrix[i],x1_matrix[i],x2_matrix[i]])
        rho += vec2rho(vec)
    rho = rho/n_samples
    return rho 

### from sms to a density matrix

def sms_rho(sms_sample, n_samples=2000):
    '''This function will generate an estimated quantum state using SMC'''
    x0_matrix = sms_sample['x0']
    x1_matrix = sms_sample['x1']
    x2_matrix = sms_sample['x2']
    x3_matrix = sms_sample['x3']
    rho = 1j * np.zeros([2,2])
    for i in range(n_samples):
        vec = np.array([x0_matrix[i],x3_matrix[i],x1_matrix[i],x2_matrix[i]])
        rho += vec2rho(vec)
    rho = rho/n_samples
    return rho

# %% [markdown]
# ## Generate a random state

# %%
x = np.random.randn(4)
print(x)
vec2rho(np.array([x[0],x[3],x[1],x[2]]))
# Out:
# [-1.43790791  0.36712175 -0.15443921 -0.25099156]
# array([[ 0.90318624+0.j        , -0.23059844-0.09700717j],
#        [-0.23059844+0.09700717j,  0.09681376+0.j        ]])

# %%
# checking the probability in x basis
(np.trace(vec2rho(np.array([x[0],x[3],x[1],x[2]]))@np.array([[0,1],[1,0]]))+1)/2
# Out:
# (0.2694015643082252+0j)

# %%
# checking the probability in y basis
(np.trace(vec2rho(np.array([x[0],x[3],x[1],x[2]]))@np.array([[0,-1j],[1j,0]]))+1)/2
# Out:
# (0.5970071672013477+0j)

# %%
def get_probs(x):
    pz = (1+1/(x[0]**2+x[1]**2+x[2]**2+x[3]**2)*(x[0]**2-(x[1]**2+x[2]**2+x[3]**2)))/2
    px = (1+1/(x[0]**2+x[1]**2+x[2]**2+x[3]**2)*2*x[0]*x[1])/2
    py = (1+1/(x[0]**2+x[1]**2+x[2]**2+x[3]**2)*2*x[0]*x[2])/2
    return np.array([px,py,pz])

# %%
get_probs(x)
# Out:
# array([0.26940156, 0.59700717, 0.90318624])

# %%
def sim_experiment(x, N = 1000):
    p = get_probs(x)
    nx = np.random.binomial(N,p[0])
    ny = np.random.binomial(N,p[1])
    nz = np.random.binomial(N,p[2])
    return np.array([nx,ny,nz])

n = sim_experiment(x,N = 1000)
print(n)
# Out:
# [281 607 912]

# %%
## running the simulations
start_time = time.time()

n_sim = 1
N = np.array([10,100,1000])  ## number of measurements 
#N = np.array([100,1000])  ## number of measurements 

particle_num = np.array([10,100,1000]) ## number of particles in SVGD

statistics = np.zeros([n_sim,N.shape[0],particle_num.shape[0]])
statistics_sms = np.zeros([n_sim,N.shape[0],particle_num.shape[0]])

for idP in range(particle_num.shape[0]):
    for idN in range(N.shape[0]):
        for idx in range(n_sim):
            true_state = np.random.randn(4)
            data = sim_experiment(true_state, N = N[idN])
            svgd, sms_sample = svgd_prestates(N[idN],z_observed=data[2],x_observed=data[0],y_observed=data[1], svgd_num_part = particle_num[idP], svgd_lear_rate = 0.01, svgd_iter = 400)
            svgd_state = svgd_rho_mean(svgd)
            sms_state = sms_rho(sms_sample)
            
            #print("svgd_state:",svgd_state)
            #print("sms_state",sms_state)
            #print("true_state:",vec2rho(np.array([true_state[0],true_state[3],true_state[1],true_state[2]]) ) )
            statistics[idx,idN,idP] = fidelity(vec2rho(np.array([true_state[0],true_state[3],true_state[1],true_state[2]])),svgd_state)
            statistics_sms[idx,idN,idP] = fidelity(vec2rho(np.array([true_state[0],true_state[3],true_state[1],true_state[2]])),sms_state)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.411
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.354
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.015
# Stage:   2 Beta: 0.047
# Stage:   3 Beta: 0.125
# Stage:   4 Beta: 0.296
# Stage:   5 Beta: 0.698
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.355
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.016
# Stage:   1 Beta: 0.048
# Stage:   2 Beta: 0.130
# Stage:   3 Beta: 0.374
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.036
# Stage:   2 Beta: 0.279
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.382
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.185
# Stage:   2 Beta: 0.514
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.018
# Stage:   3 Beta: 0.046
# Stage:   4 Beta: 0.110
# Stage:   5 Beta: 0.279
# Stage:   6 Beta: 0.711
# Stage:   7 Beta: 1.000
# --- 489.0401654243469 seconds ---

# %%
print("svgd-fidliety:",statistics)
print("")
print("sms-fidelity:",statistics_sms)
# Out:
# svgd-fidliety: [[[0.96266958 0.93229879 0.92733316]
#   [0.99655794 0.99660206 0.97544072]
#   [0.97426304 0.99560773 0.9995369 ]]]
#
# sms-fidelity: [[[0.94986312 0.92993639 0.92887477]
#   [0.9972399  0.99696025 0.99393224]
#   [0.99652215 0.9999434  0.999495  ]]]

# %%
ave_statistics = np.mean(statistics, axis = 0)
ave_statistics_sms= np.mean(statistics_sms, axis = 0)
print("svgd:",ave_statistics)
print("")
print("ave_sms",ave_statistics_sms)
#ave_statistics[0,:]
# Out:
# svgd: [[0.96266958 0.93229879 0.92733316]
#  [0.99655794 0.99660206 0.97544072]
#  [0.97426304 0.99560773 0.9995369 ]]
#
# ave_sms [[0.94986312 0.92993639 0.92887477]
#  [0.9972399  0.99696025 0.99393224]
#  [0.99652215 0.9999434  0.999495  ]]

# %%
ave_statistics = np.mean(statistics, axis = 0)
plt.rcParams["figure.figsize"] = 8, 5
plt.plot(N, ave_statistics[:,0], label = str(particle_num[0])+" particles-svgd")
plt.plot(N, ave_statistics[:,1], label = str(particle_num[1])+" particles-svgd")
plt.plot(N, ave_statistics[:,2], label = str(particle_num[2])+" particles-svgd")

plt.plot(N, ave_statistics_sms[:,0], label = str(particle_num[0])+" particles-sms")
plt.plot(N, ave_statistics_sms[:,1], label = str(particle_num[1])+" particles-sms")
plt.plot(N, ave_statistics_sms[:,2], label = str(particle_num[2])+" particles-sms")
plt.legend(fontsize=10,loc=0)
plt.ylabel("Average Fidelity")
plt.xlabel("Number of particles")
plt.grid()

# %%
plt.plot(N, ave_statistics[0,:], label = str(N[0])+" measurements")
plt.plot(N, ave_statistics[1,:], label = str(N[1])+" measurements")
plt.plot(N, ave_statistics[2,:], label = str(N[2])+" measurements")

plt.plot(N, ave_statistics_sms[0,:], label = str(N[0])+" measurements-sms")
plt.plot(N, ave_statistics_sms[1,:], label = str(N[1])+" measurements-sms")
plt.plot(N, ave_statistics_sms[2,:], label = str(N[2])+" measurements-sms")
plt.legend(fontsize=10,loc=0)
plt.ylabel("Average Fidelity")
plt.xlabel("Number of measurements")
plt.grid()

# %% [markdown]
# ## Extra plots

# %%
n_samples = 1000
fullsamples = svgd.sample(n_samples)
x0_matrix = fullsamples['x0']
x1_matrix = fullsamples['x1']
x2_matrix = fullsamples['x2']
x3_matrix = fullsamples['x3']
ax =sns.kdeplot(x0_matrix, label="SVGD")

# %%
bx =sns.kdeplot(x1_matrix, label="SVGD")

# %%
cx =sns.kdeplot(x2_matrix, label="SVGD")

# %%
dx =sns.kdeplot(x3_matrix, label="SVGD")

# %% [markdown]
# ## More simulations

# %%
## running the simulations
start_time = time.time()

n_sim = 70
N = np.array([10,100,1000])  ## number of measurements 

particle_num = np.array([10,100,1000]) ## number of particles in SVGD

statistics = np.zeros([n_sim,N.shape[0],particle_num.shape[0]])
statistics_sms = np.zeros([n_sim,N.shape[0],particle_num.shape[0]])

for idP in range(particle_num.shape[0]):

    for idN in range(N.shape[0]):

        for idx in range(n_sim):
            true_state = np.random.randn(4)
            data = sim_experiment(true_state, N = N[idN])
            svgd, sms_sample = svgd_prestates(N[idN],z_observed=data[2],x_observed=data[0],y_observed=data[1], svgd_num_part = particle_num[idP], svgd_lear_rate = 0.01, svgd_iter = 400)
            svgd_state = svgd_rho_mean(svgd)
            sms_state = sms_rho(sms_sample)
            #print("svgd_state:",svgd_state)
            #print("sms_state",sms_state)
            #print("true_state:",vec2rho(np.array([true_state[0],true_state[3],true_state[1],true_state[2]]) ) )
            statistics[idx,idN,idP] = fidelity(vec2rho(np.array([true_state[0],true_state[3],true_state[1],true_state[2]])),svgd_state)
            statistics_sms[idx,idN,idP] = fidelity(vec2rho(np.array([true_state[0],true_state[3],true_state[1],true_state[2]])),sms_state)

            
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.176
# Stage:   1 Beta: 0.517
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.213
# Stage:   1 Beta: 0.613
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.539
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.231
# Stage:   1 Beta: 0.740
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.458
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.345
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.167
# Stage:   1 Beta: 0.480
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.242
# Stage:   1 Beta: 0.731
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.343
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.329
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.395
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.393
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.230
# Stage:   1 Beta: 0.756
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.293
# Stage:   1 Beta: 0.953
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.245
# Stage:   1 Beta: 0.756
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.396
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.266
# Stage:   1 Beta: 0.802
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.502
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.253
# Stage:   1 Beta: 0.798
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.421
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.375
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.323
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.385
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.317
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.376
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.212
# Stage:   1 Beta: 0.681
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.335
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.245
# Stage:   1 Beta: 0.726
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.225
# Stage:   1 Beta: 0.680
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.109
# Stage:   1 Beta: 0.326
# Stage:   2 Beta: 0.956
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.388
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.424
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.127
# Stage:   1 Beta: 0.397
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.402
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.389
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.138
# Stage:   1 Beta: 0.429
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.209
# Stage:   1 Beta: 0.619
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.388
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.369
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.224
# Stage:   1 Beta: 0.685
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.084
# Stage:   1 Beta: 0.241
# Stage:   2 Beta: 0.620
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.357
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.089
# Stage:   1 Beta: 0.251
# Stage:   2 Beta: 0.646
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.433
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.396
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.372
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.098
# Stage:   1 Beta: 0.290
# Stage:   2 Beta: 0.761
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.383
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.391
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.190
# Stage:   1 Beta: 0.586
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.328
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.387
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.206
# Stage:   1 Beta: 0.583
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.190
# Stage:   1 Beta: 0.545
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.302
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.194
# Stage:   1 Beta: 0.588
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.167
# Stage:   1 Beta: 0.482
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.272
# Stage:   1 Beta: 0.893
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.278
# Stage:   1 Beta: 0.878
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.123
# Stage:   1 Beta: 0.391
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.185
# Stage:   1 Beta: 0.567
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.227
# Stage:   1 Beta: 0.686
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.555
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.376
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.645
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.502
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.385
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.424
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.235
# Stage:   1 Beta: 0.776
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.160
# Stage:   1 Beta: 0.454
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.039
# Stage:   1 Beta: 0.313
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.047
# Stage:   1 Beta: 0.170
# Stage:   2 Beta: 0.449
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.021
# Stage:   1 Beta: 0.068
# Stage:   2 Beta: 0.210
# Stage:   3 Beta: 0.565
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.034
# Stage:   1 Beta: 0.100
# Stage:   2 Beta: 0.235
# Stage:   3 Beta: 0.586
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.040
# Stage:   1 Beta: 0.139
# Stage:   2 Beta: 0.383
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.012
# Stage:   1 Beta: 0.036
# Stage:   2 Beta: 0.097
# Stage:   3 Beta: 0.253
# Stage:   4 Beta: 0.662
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.021
# Stage:   1 Beta: 0.065
# Stage:   2 Beta: 0.191
# Stage:   3 Beta: 0.589
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.024
# Stage:   1 Beta: 0.074
# Stage:   2 Beta: 0.206
# Stage:   3 Beta: 0.609
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.045
# Stage:   1 Beta: 0.168
# Stage:   2 Beta: 0.496
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.049
# Stage:   1 Beta: 0.168
# Stage:   2 Beta: 0.436
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.026
# Stage:   1 Beta: 0.085
# Stage:   2 Beta: 0.227
# Stage:   3 Beta: 0.562
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.029
# Stage:   1 Beta: 0.093
# Stage:   2 Beta: 0.273
# Stage:   3 Beta: 0.796
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.036
# Stage:   1 Beta: 0.117
# Stage:   2 Beta: 0.334
# Stage:   3 Beta: 0.999
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.036
# Stage:   1 Beta: 0.124
# Stage:   2 Beta: 0.386
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.023
# Stage:   1 Beta: 0.075
# Stage:   2 Beta: 0.190
# Stage:   3 Beta: 0.463
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.028
# Stage:   1 Beta: 0.085
# Stage:   2 Beta: 0.232
# Stage:   3 Beta: 0.645
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.039
# Stage:   1 Beta: 0.299
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.028
# Stage:   1 Beta: 0.087
# Stage:   2 Beta: 0.256
# Stage:   3 Beta: 0.759
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.039
# Stage:   1 Beta: 0.136
# Stage:   2 Beta: 0.372
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.014
# Stage:   1 Beta: 0.045
# Stage:   2 Beta: 0.126
# Stage:   3 Beta: 0.357
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.034
# Stage:   1 Beta: 0.110
# Stage:   2 Beta: 0.325
# Stage:   3 Beta: 0.947
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.378
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.041
# Stage:   1 Beta: 0.189
# Stage:   2 Beta: 0.522
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.142
# Stage:   2 Beta: 0.386
# Stage:   3 Beta: 0.913
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.350
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.029
# Stage:   1 Beta: 0.094
# Stage:   2 Beta: 0.249
# Stage:   3 Beta: 0.595
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.014
# Stage:   1 Beta: 0.043
# Stage:   2 Beta: 0.121
# Stage:   3 Beta: 0.338
# Stage:   4 Beta: 0.969
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.015
# Stage:   1 Beta: 0.045
# Stage:   2 Beta: 0.128
# Stage:   3 Beta: 0.362
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.031
# Stage:   1 Beta: 0.100
# Stage:   2 Beta: 0.297
# Stage:   3 Beta: 0.892
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.028
# Stage:   1 Beta: 0.087
# Stage:   2 Beta: 0.235
# Stage:   3 Beta: 0.657
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.020
# Stage:   1 Beta: 0.064
# Stage:   2 Beta: 0.184
# Stage:   3 Beta: 0.528
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.016
# Stage:   1 Beta: 0.050
# Stage:   2 Beta: 0.138
# Stage:   3 Beta: 0.363
# Stage:   4 Beta: 0.905
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.044
# Stage:   1 Beta: 0.159
# Stage:   2 Beta: 0.481
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.029
# Stage:   1 Beta: 0.089
# Stage:   2 Beta: 0.248
# Stage:   3 Beta: 0.724
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.021
# Stage:   1 Beta: 0.065
# Stage:   2 Beta: 0.187
# Stage:   3 Beta: 0.554
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.014
# Stage:   1 Beta: 0.041
# Stage:   2 Beta: 0.112
# Stage:   3 Beta: 0.302
# Stage:   4 Beta: 0.818
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.040
# Stage:   1 Beta: 0.317
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.037
# Stage:   1 Beta: 0.126
# Stage:   2 Beta: 0.368
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.037
# Stage:   1 Beta: 0.122
# Stage:   2 Beta: 0.354
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.018
# Stage:   1 Beta: 0.050
# Stage:   2 Beta: 0.128
# Stage:   3 Beta: 0.339
# Stage:   4 Beta: 0.882
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.025
# Stage:   1 Beta: 0.080
# Stage:   2 Beta: 0.238
# Stage:   3 Beta: 0.692
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.039
# Stage:   1 Beta: 0.129
# Stage:   2 Beta: 0.379
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.040
# Stage:   1 Beta: 0.333
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.012
# Stage:   1 Beta: 0.039
# Stage:   2 Beta: 0.111
# Stage:   3 Beta: 0.308
# Stage:   4 Beta: 0.846
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.047
# Stage:   1 Beta: 0.210
# Stage:   2 Beta: 0.642
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.040
# Stage:   1 Beta: 0.141
# Stage:   2 Beta: 0.415
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.012
# Stage:   1 Beta: 0.040
# Stage:   2 Beta: 0.110
# Stage:   3 Beta: 0.315
# Stage:   4 Beta: 0.888
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.028
# Stage:   1 Beta: 0.090
# Stage:   2 Beta: 0.259
# Stage:   3 Beta: 0.780
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.048
# Stage:   1 Beta: 0.194
# Stage:   2 Beta: 0.589
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.025
# Stage:   1 Beta: 0.077
# Stage:   2 Beta: 0.229
# Stage:   3 Beta: 0.683
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.038
# Stage:   1 Beta: 0.295
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.036
# Stage:   1 Beta: 0.120
# Stage:   2 Beta: 0.346
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.024
# Stage:   1 Beta: 0.077
# Stage:   2 Beta: 0.217
# Stage:   3 Beta: 0.631
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.029
# Stage:   1 Beta: 0.095
# Stage:   2 Beta: 0.278
# Stage:   3 Beta: 0.723
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.039
# Stage:   1 Beta: 0.309
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.039
# Stage:   1 Beta: 0.133
# Stage:   2 Beta: 0.393
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.016
# Stage:   1 Beta: 0.053
# Stage:   2 Beta: 0.145
# Stage:   3 Beta: 0.368
# Stage:   4 Beta: 0.921
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.011
# Stage:   1 Beta: 0.035
# Stage:   2 Beta: 0.091
# Stage:   3 Beta: 0.251
# Stage:   4 Beta: 0.719
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.040
# Stage:   1 Beta: 0.341
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.024
# Stage:   1 Beta: 0.074
# Stage:   2 Beta: 0.202
# Stage:   3 Beta: 0.559
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.352
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.025
# Stage:   1 Beta: 0.078
# Stage:   2 Beta: 0.221
# Stage:   3 Beta: 0.667
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.043
# Stage:   1 Beta: 0.423
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.040
# Stage:   1 Beta: 0.324
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.050
# Stage:   1 Beta: 0.217
# Stage:   2 Beta: 0.649
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.014
# Stage:   1 Beta: 0.043
# Stage:   2 Beta: 0.132
# Stage:   3 Beta: 0.367
# Stage:   4 Beta: 0.917
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.034
# Stage:   1 Beta: 0.116
# Stage:   2 Beta: 0.317
# Stage:   3 Beta: 0.864
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.012
# Stage:   1 Beta: 0.038
# Stage:   2 Beta: 0.105
# Stage:   3 Beta: 0.291
# Stage:   4 Beta: 0.824
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.039
# Stage:   1 Beta: 0.296
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.038
# Stage:   1 Beta: 0.127
# Stage:   2 Beta: 0.376
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.019
# Stage:   3 Beta: 0.056
# Stage:   4 Beta: 0.166
# Stage:   5 Beta: 0.496
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.021
# Stage:   2 Beta: 0.066
# Stage:   3 Beta: 0.182
# Stage:   4 Beta: 0.436
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.016
# Stage:   3 Beta: 0.048
# Stage:   4 Beta: 0.143
# Stage:   5 Beta: 0.362
# Stage:   6 Beta: 0.857
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.014
# Stage:   3 Beta: 0.039
# Stage:   4 Beta: 0.096
# Stage:   5 Beta: 0.238
# Stage:   6 Beta: 0.602
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.017
# Stage:   2 Beta: 0.049
# Stage:   3 Beta: 0.140
# Stage:   4 Beta: 0.400
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.012
# Stage:   2 Beta: 0.030
# Stage:   3 Beta: 0.072
# Stage:   4 Beta: 0.175
# Stage:   5 Beta: 0.443
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.010
# Stage:   3 Beta: 0.026
# Stage:   4 Beta: 0.076
# Stage:   5 Beta: 0.218
# Stage:   6 Beta: 0.618
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.008
# Stage:   2 Beta: 0.024
# Stage:   3 Beta: 0.069
# Stage:   4 Beta: 0.193
# Stage:   5 Beta: 0.559
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.035
# Stage:   2 Beta: 0.281
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.019
# Stage:   3 Beta: 0.056
# Stage:   4 Beta: 0.167
# Stage:   5 Beta: 0.477
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.024
# Stage:   2 Beta: 0.073
# Stage:   3 Beta: 0.199
# Stage:   4 Beta: 0.477
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.021
# Stage:   3 Beta: 0.060
# Stage:   4 Beta: 0.161
# Stage:   5 Beta: 0.389
# Stage:   6 Beta: 0.967
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.035
# Stage:   2 Beta: 0.112
# Stage:   3 Beta: 0.317
# Stage:   4 Beta: 0.873
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.012
# Stage:   3 Beta: 0.036
# Stage:   4 Beta: 0.094
# Stage:   5 Beta: 0.230
# Stage:   6 Beta: 0.565
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.035
# Stage:   2 Beta: 0.123
# Stage:   3 Beta: 0.386
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.015
# Stage:   2 Beta: 0.044
# Stage:   3 Beta: 0.127
# Stage:   4 Beta: 0.364
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.020
# Stage:   2 Beta: 0.059
# Stage:   3 Beta: 0.174
# Stage:   4 Beta: 0.497
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.013
# Stage:   3 Beta: 0.035
# Stage:   4 Beta: 0.098
# Stage:   5 Beta: 0.262
# Stage:   6 Beta: 0.724
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.012
# Stage:   3 Beta: 0.034
# Stage:   4 Beta: 0.096
# Stage:   5 Beta: 0.276
# Stage:   6 Beta: 0.797
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.019
# Stage:   3 Beta: 0.054
# Stage:   4 Beta: 0.156
# Stage:   5 Beta: 0.438
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.008
# Stage:   2 Beta: 0.025
# Stage:   3 Beta: 0.067
# Stage:   4 Beta: 0.158
# Stage:   5 Beta: 0.385
# Stage:   6 Beta: 0.939
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.012
# Stage:   2 Beta: 0.034
# Stage:   3 Beta: 0.097
# Stage:   4 Beta: 0.255
# Stage:   5 Beta: 0.658
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.031
# Stage:   2 Beta: 0.227
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.014
# Stage:   3 Beta: 0.040
# Stage:   4 Beta: 0.115
# Stage:   5 Beta: 0.303
# Stage:   6 Beta: 0.755
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.039
# Stage:   2 Beta: 0.162
# Stage:   3 Beta: 0.465
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.012
# Stage:   2 Beta: 0.034
# Stage:   3 Beta: 0.104
# Stage:   4 Beta: 0.312
# Stage:   5 Beta: 0.910
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.010
# Stage:   3 Beta: 0.028
# Stage:   4 Beta: 0.079
# Stage:   5 Beta: 0.207
# Stage:   6 Beta: 0.502
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.011
# Stage:   3 Beta: 0.031
# Stage:   4 Beta: 0.085
# Stage:   5 Beta: 0.236
# Stage:   6 Beta: 0.655
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.013
# Stage:   2 Beta: 0.037
# Stage:   3 Beta: 0.095
# Stage:   4 Beta: 0.229
# Stage:   5 Beta: 0.579
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.023
# Stage:   2 Beta: 0.070
# Stage:   3 Beta: 0.208
# Stage:   4 Beta: 0.624
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.012
# Stage:   2 Beta: 0.033
# Stage:   3 Beta: 0.095
# Stage:   4 Beta: 0.261
# Stage:   5 Beta: 0.726
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.034
# Stage:   2 Beta: 0.233
# Stage:   3 Beta: 0.945
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.006
# Stage:   1 Beta: 0.028
# Stage:   2 Beta: 0.079
# Stage:   3 Beta: 0.182
# Stage:   4 Beta: 0.444
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.015
# Stage:   3 Beta: 0.043
# Stage:   4 Beta: 0.109
# Stage:   5 Beta: 0.273
# Stage:   6 Beta: 0.678
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.015
# Stage:   3 Beta: 0.037
# Stage:   4 Beta: 0.095
# Stage:   5 Beta: 0.249
# Stage:   6 Beta: 0.639
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.003
# Stage:   2 Beta: 0.008
# Stage:   3 Beta: 0.022
# Stage:   4 Beta: 0.060
# Stage:   5 Beta: 0.165
# Stage:   6 Beta: 0.448
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.011
# Stage:   3 Beta: 0.031
# Stage:   4 Beta: 0.089
# Stage:   5 Beta: 0.239
# Stage:   6 Beta: 0.592
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.036
# Stage:   2 Beta: 0.114
# Stage:   3 Beta: 0.328
# Stage:   4 Beta: 0.838
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.029
# Stage:   2 Beta: 0.090
# Stage:   3 Beta: 0.270
# Stage:   4 Beta: 0.823
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.030
# Stage:   2 Beta: 0.100
# Stage:   3 Beta: 0.302
# Stage:   4 Beta: 0.861
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.018
# Stage:   2 Beta: 0.053
# Stage:   3 Beta: 0.154
# Stage:   4 Beta: 0.461
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.041
# Stage:   2 Beta: 0.148
# Stage:   3 Beta: 0.445
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.029
# Stage:   2 Beta: 0.089
# Stage:   3 Beta: 0.216
# Stage:   4 Beta: 0.486
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.018
# Stage:   3 Beta: 0.044
# Stage:   4 Beta: 0.110
# Stage:   5 Beta: 0.272
# Stage:   6 Beta: 0.701
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.013
# Stage:   2 Beta: 0.037
# Stage:   3 Beta: 0.106
# Stage:   4 Beta: 0.301
# Stage:   5 Beta: 0.866
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.006
# Stage:   1 Beta: 0.027
# Stage:   2 Beta: 0.082
# Stage:   3 Beta: 0.230
# Stage:   4 Beta: 0.562
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.003
# Stage:   2 Beta: 0.007
# Stage:   3 Beta: 0.020
# Stage:   4 Beta: 0.056
# Stage:   5 Beta: 0.155
# Stage:   6 Beta: 0.451
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.010
# Stage:   2 Beta: 0.027
# Stage:   3 Beta: 0.074
# Stage:   4 Beta: 0.212
# Stage:   5 Beta: 0.606
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.019
# Stage:   2 Beta: 0.056
# Stage:   3 Beta: 0.161
# Stage:   4 Beta: 0.448
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.011
# Stage:   3 Beta: 0.029
# Stage:   4 Beta: 0.083
# Stage:   5 Beta: 0.245
# Stage:   6 Beta: 0.686
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.018
# Stage:   3 Beta: 0.045
# Stage:   4 Beta: 0.112
# Stage:   5 Beta: 0.284
# Stage:   6 Beta: 0.740
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.043
# Stage:   2 Beta: 0.259
# Stage:   3 Beta: 0.729
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.014
# Stage:   2 Beta: 0.040
# Stage:   3 Beta: 0.097
# Stage:   4 Beta: 0.236
# Stage:   5 Beta: 0.578
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.008
# Stage:   2 Beta: 0.023
# Stage:   3 Beta: 0.057
# Stage:   4 Beta: 0.139
# Stage:   5 Beta: 0.347
# Stage:   6 Beta: 0.879
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.016
# Stage:   2 Beta: 0.047
# Stage:   3 Beta: 0.123
# Stage:   4 Beta: 0.299
# Stage:   5 Beta: 0.761
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.024
# Stage:   2 Beta: 0.072
# Stage:   3 Beta: 0.211
# Stage:   4 Beta: 0.625
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.009
# Stage:   2 Beta: 0.026
# Stage:   3 Beta: 0.067
# Stage:   4 Beta: 0.168
# Stage:   5 Beta: 0.422
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.013
# Stage:   3 Beta: 0.038
# Stage:   4 Beta: 0.105
# Stage:   5 Beta: 0.262
# Stage:   6 Beta: 0.644
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.019
# Stage:   2 Beta: 0.053
# Stage:   3 Beta: 0.127
# Stage:   4 Beta: 0.314
# Stage:   5 Beta: 0.811
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.012
# Stage:   3 Beta: 0.032
# Stage:   4 Beta: 0.079
# Stage:   5 Beta: 0.195
# Stage:   6 Beta: 0.486
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.013
# Stage:   2 Beta: 0.036
# Stage:   3 Beta: 0.087
# Stage:   4 Beta: 0.212
# Stage:   5 Beta: 0.529
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.014
# Stage:   2 Beta: 0.042
# Stage:   3 Beta: 0.122
# Stage:   4 Beta: 0.364
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.014
# Stage:   3 Beta: 0.042
# Stage:   4 Beta: 0.113
# Stage:   5 Beta: 0.277
# Stage:   6 Beta: 0.708
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.009
# Stage:   2 Beta: 0.025
# Stage:   3 Beta: 0.074
# Stage:   4 Beta: 0.221
# Stage:   5 Beta: 0.639
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.015
# Stage:   3 Beta: 0.038
# Stage:   4 Beta: 0.095
# Stage:   5 Beta: 0.249
# Stage:   6 Beta: 0.623
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.009
# Stage:   2 Beta: 0.026
# Stage:   3 Beta: 0.076
# Stage:   4 Beta: 0.226
# Stage:   5 Beta: 0.708
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.012
# Stage:   3 Beta: 0.033
# Stage:   4 Beta: 0.099
# Stage:   5 Beta: 0.298
# Stage:   6 Beta: 0.875
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.009
# Stage:   2 Beta: 0.025
# Stage:   3 Beta: 0.074
# Stage:   4 Beta: 0.214
# Stage:   5 Beta: 0.626
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.014
# Stage:   2 Beta: 0.042
# Stage:   3 Beta: 0.120
# Stage:   4 Beta: 0.313
# Stage:   5 Beta: 0.748
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.008
# Stage:   2 Beta: 0.023
# Stage:   3 Beta: 0.060
# Stage:   4 Beta: 0.144
# Stage:   5 Beta: 0.350
# Stage:   6 Beta: 0.879
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.552
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.346
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.104
# Stage:   1 Beta: 0.306
# Stage:   2 Beta: 0.806
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.389
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.265
# Stage:   1 Beta: 0.798
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.127
# Stage:   1 Beta: 0.364
# Stage:   2 Beta: 0.955
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.407
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.257
# Stage:   1 Beta: 0.813
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.279
# Stage:   1 Beta: 0.890
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.363
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.369
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.283
# Stage:   1 Beta: 0.859
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.392
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.321
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.413
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.418
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.204
# Stage:   1 Beta: 0.660
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.119
# Stage:   1 Beta: 0.360
# Stage:   2 Beta: 0.986
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.201
# Stage:   1 Beta: 0.648
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.376
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.513
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.187
# Stage:   1 Beta: 0.523
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.422
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.384
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.181
# Stage:   1 Beta: 0.589
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.177
# Stage:   1 Beta: 0.573
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.089
# Stage:   1 Beta: 0.260
# Stage:   2 Beta: 0.658
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.323
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.117
# Stage:   1 Beta: 0.358
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.394
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.185
# Stage:   1 Beta: 0.548
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.103
# Stage:   1 Beta: 0.295
# Stage:   2 Beta: 0.771
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.350
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.576
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.438
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.385
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.157
# Stage:   1 Beta: 0.496
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.342
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.322
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.504
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.377
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.177
# Stage:   1 Beta: 0.553
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.295
# Stage:   1 Beta: 0.958
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.386
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.420
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.373
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.085
# Stage:   1 Beta: 0.242
# Stage:   2 Beta: 0.604
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.406
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.086
# Stage:   1 Beta: 0.249
# Stage:   2 Beta: 0.654
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.109
# Stage:   1 Beta: 0.323
# Stage:   2 Beta: 0.853
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.321
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.485
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.106
# Stage:   1 Beta: 0.313
# Stage:   2 Beta: 0.810
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.376
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.400
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.459
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.319
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.374
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.215
# Stage:   1 Beta: 0.655
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.405
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.405
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.224
# Stage:   1 Beta: 0.640
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.405
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.266
# Stage:   1 Beta: 0.855
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.128
# Stage:   1 Beta: 0.382
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.390
# Stage:   1 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.107
# Stage:   1 Beta: 0.325
# Stage:   2 Beta: 0.901
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.156
# Stage:   1 Beta: 0.506
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.177
# Stage:   1 Beta: 0.554
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.308
# Stage:   1 Beta: 0.999
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.031
# Stage:   1 Beta: 0.100
# Stage:   2 Beta: 0.271
# Stage:   3 Beta: 0.711
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.039
# Stage:   1 Beta: 0.331
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.017
# Stage:   1 Beta: 0.053
# Stage:   2 Beta: 0.152
# Stage:   3 Beta: 0.426
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.016
# Stage:   1 Beta: 0.048
# Stage:   2 Beta: 0.134
# Stage:   3 Beta: 0.374
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.018
# Stage:   1 Beta: 0.059
# Stage:   2 Beta: 0.175
# Stage:   3 Beta: 0.495
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.036
# Stage:   1 Beta: 0.118
# Stage:   2 Beta: 0.318
# Stage:   3 Beta: 0.846
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.019
# Stage:   1 Beta: 0.061
# Stage:   2 Beta: 0.175
# Stage:   3 Beta: 0.505
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.014
# Stage:   1 Beta: 0.044
# Stage:   2 Beta: 0.121
# Stage:   3 Beta: 0.311
# Stage:   4 Beta: 0.782
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.014
# Stage:   1 Beta: 0.044
# Stage:   2 Beta: 0.122
# Stage:   3 Beta: 0.336
# Stage:   4 Beta: 0.941
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.338
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.017
# Stage:   1 Beta: 0.051
# Stage:   2 Beta: 0.145
# Stage:   3 Beta: 0.406
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.045
# Stage:   1 Beta: 0.160
# Stage:   2 Beta: 0.466
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.143
# Stage:   2 Beta: 0.392
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.044
# Stage:   1 Beta: 0.353
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.043
# Stage:   1 Beta: 0.144
# Stage:   2 Beta: 0.428
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.043
# Stage:   1 Beta: 0.409
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.022
# Stage:   1 Beta: 0.070
# Stage:   2 Beta: 0.204
# Stage:   3 Beta: 0.604
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.026
# Stage:   1 Beta: 0.080
# Stage:   2 Beta: 0.224
# Stage:   3 Beta: 0.616
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.038
# Stage:   1 Beta: 0.240
# Stage:   2 Beta: 0.738
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.037
# Stage:   1 Beta: 0.124
# Stage:   2 Beta: 0.356
# Stage:   3 Beta: 0.969
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.053
# Stage:   1 Beta: 0.233
# Stage:   2 Beta: 0.646
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.033
# Stage:   1 Beta: 0.105
# Stage:   2 Beta: 0.274
# Stage:   3 Beta: 0.656
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.038
# Stage:   1 Beta: 0.109
# Stage:   2 Beta: 0.257
# Stage:   3 Beta: 0.631
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.026
# Stage:   1 Beta: 0.081
# Stage:   2 Beta: 0.236
# Stage:   3 Beta: 0.680
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.262
# Stage:   2 Beta: 0.755
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.011
# Stage:   1 Beta: 0.033
# Stage:   2 Beta: 0.091
# Stage:   3 Beta: 0.260
# Stage:   4 Beta: 0.746
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.042
# Stage:   1 Beta: 0.334
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.014
# Stage:   1 Beta: 0.043
# Stage:   2 Beta: 0.117
# Stage:   3 Beta: 0.303
# Stage:   4 Beta: 0.760
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.029
# Stage:   1 Beta: 0.093
# Stage:   2 Beta: 0.271
# Stage:   3 Beta: 0.780
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.023
# Stage:   1 Beta: 0.067
# Stage:   2 Beta: 0.184
# Stage:   3 Beta: 0.493
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.037
# Stage:   1 Beta: 0.124
# Stage:   2 Beta: 0.376
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.016
# Stage:   1 Beta: 0.048
# Stage:   2 Beta: 0.131
# Stage:   3 Beta: 0.360
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.057
# Stage:   1 Beta: 0.224
# Stage:   2 Beta: 0.556
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.038
# Stage:   1 Beta: 0.301
# Stage:   2 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.047
# Stage:   1 Beta: 0.229
# Stage:   2 Beta: 0.646
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.022
# ...
# Stage:   2 Beta: 0.237
# Stage:   3 Beta: 0.678
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.014
# Stage:   1 Beta: 0.041
# Stage:   2 Beta: 0.118
# Stage:   3 Beta: 0.332
# Stage:   4 Beta: 0.914
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.026
# Stage:   1 Beta: 0.083
# Stage:   2 Beta: 0.233
# Stage:   3 Beta: 0.607
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.012
# Stage:   1 Beta: 0.038
# Stage:   2 Beta: 0.100
# Stage:   3 Beta: 0.278
# Stage:   4 Beta: 0.798
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.049
# Stage:   1 Beta: 0.259
# Stage:   2 Beta: 0.805
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.020
# Stage:   1 Beta: 0.061
# Stage:   2 Beta: 0.190
# Stage:   3 Beta: 0.547
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.017
# Stage:   1 Beta: 0.050
# Stage:   2 Beta: 0.146
# Stage:   3 Beta: 0.440
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.011
# Stage:   3 Beta: 0.032
# Stage:   4 Beta: 0.089
# Stage:   5 Beta: 0.247
# Stage:   6 Beta: 0.617
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.011
# Stage:   2 Beta: 0.033
# Stage:   3 Beta: 0.087
# Stage:   4 Beta: 0.207
# Stage:   5 Beta: 0.521
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.006
# Stage:   1 Beta: 0.025
# Stage:   2 Beta: 0.071
# Stage:   3 Beta: 0.173
# Stage:   4 Beta: 0.420
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.017
# Stage:   3 Beta: 0.043
# Stage:   4 Beta: 0.110
# Stage:   5 Beta: 0.279
# Stage:   6 Beta: 0.735
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.017
# Stage:   3 Beta: 0.048
# Stage:   4 Beta: 0.138
# Stage:   5 Beta: 0.410
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.011
# Stage:   3 Beta: 0.031
# Stage:   4 Beta: 0.090
# Stage:   5 Beta: 0.255
# Stage:   6 Beta: 0.634
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.003
# Stage:   2 Beta: 0.009
# Stage:   3 Beta: 0.025
# Stage:   4 Beta: 0.071
# Stage:   5 Beta: 0.207
# Stage:   6 Beta: 0.581
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.019
# Stage:   2 Beta: 0.053
# Stage:   3 Beta: 0.162
# Stage:   4 Beta: 0.502
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.016
# Stage:   3 Beta: 0.039
# Stage:   4 Beta: 0.098
# Stage:   5 Beta: 0.245
# Stage:   6 Beta: 0.634
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.031
# Stage:   2 Beta: 0.225
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.021
# Stage:   3 Beta: 0.059
# Stage:   4 Beta: 0.171
# Stage:   5 Beta: 0.498
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.018
# Stage:   2 Beta: 0.054
# Stage:   3 Beta: 0.153
# Stage:   4 Beta: 0.372
# Stage:   5 Beta: 0.917
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.034
# Stage:   2 Beta: 0.119
# Stage:   3 Beta: 0.345
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.004
# Stage:   2 Beta: 0.010
# Stage:   3 Beta: 0.028
# Stage:   4 Beta: 0.080
# Stage:   5 Beta: 0.219
# Stage:   6 Beta: 0.631
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.011
# Stage:   2 Beta: 0.028
# Stage:   3 Beta: 0.070
# Stage:   4 Beta: 0.173
# Stage:   5 Beta: 0.427
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.021
# Stage:   2 Beta: 0.064
# Stage:   3 Beta: 0.196
# Stage:   4 Beta: 0.563
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.020
# Stage:   2 Beta: 0.060
# Stage:   3 Beta: 0.181
# Stage:   4 Beta: 0.524
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.032
# Stage:   2 Beta: 0.234
# Stage:   3 Beta: 0.949
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.019
# Stage:   3 Beta: 0.051
# Stage:   4 Beta: 0.130
# Stage:   5 Beta: 0.325
# Stage:   6 Beta: 0.822
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.019
# Stage:   2 Beta: 0.051
# Stage:   3 Beta: 0.121
# Stage:   4 Beta: 0.293
# Stage:   5 Beta: 0.747
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.009
# Stage:   2 Beta: 0.025
# Stage:   3 Beta: 0.072
# Stage:   4 Beta: 0.216
# Stage:   5 Beta: 0.653
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.011
# Stage:   2 Beta: 0.032
# Stage:   3 Beta: 0.094
# Stage:   4 Beta: 0.245
# Stage:   5 Beta: 0.592
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.009
# Stage:   2 Beta: 0.024
# Stage:   3 Beta: 0.068
# Stage:   4 Beta: 0.198
# Stage:   5 Beta: 0.549
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.010
# Stage:   2 Beta: 0.026
# Stage:   3 Beta: 0.063
# Stage:   4 Beta: 0.158
# Stage:   5 Beta: 0.408
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.013
# Stage:   2 Beta: 0.037
# Stage:   3 Beta: 0.109
# Stage:   4 Beta: 0.319
# Stage:   5 Beta: 0.914
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.021
# Stage:   3 Beta: 0.056
# Stage:   4 Beta: 0.157
# Stage:   5 Beta: 0.425
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.029
# Stage:   2 Beta: 0.089
# Stage:   3 Beta: 0.245
# Stage:   4 Beta: 0.673
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.008
# Stage:   2 Beta: 0.022
# Stage:   3 Beta: 0.067
# Stage:   4 Beta: 0.193
# Stage:   5 Beta: 0.483
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.015
# Stage:   3 Beta: 0.042
# Stage:   4 Beta: 0.113
# Stage:   5 Beta: 0.311
# Stage:   6 Beta: 0.844
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.019
# Stage:   3 Beta: 0.045
# Stage:   4 Beta: 0.112
# Stage:   5 Beta: 0.281
# Stage:   6 Beta: 0.721
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.035
# Stage:   2 Beta: 0.262
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.028
# Stage:   2 Beta: 0.087
# Stage:   3 Beta: 0.252
# Stage:   4 Beta: 0.681
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.014
# Stage:   2 Beta: 0.038
# Stage:   3 Beta: 0.092
# Stage:   4 Beta: 0.218
# Stage:   5 Beta: 0.579
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.019
# Stage:   3 Beta: 0.047
# Stage:   4 Beta: 0.119
# Stage:   5 Beta: 0.298
# Stage:   6 Beta: 0.763
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.003
# Stage:   2 Beta: 0.008
# Stage:   3 Beta: 0.021
# Stage:   4 Beta: 0.060
# Stage:   5 Beta: 0.178
# Stage:   6 Beta: 0.492
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.009
# Stage:   2 Beta: 0.022
# Stage:   3 Beta: 0.053
# Stage:   4 Beta: 0.135
# Stage:   5 Beta: 0.349
# Stage:   6 Beta: 0.878
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.040
# Stage:   2 Beta: 0.219
# Stage:   3 Beta: 0.668
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.021
# Stage:   3 Beta: 0.061
# Stage:   4 Beta: 0.162
# Stage:   5 Beta: 0.396
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.014
# Stage:   3 Beta: 0.038
# Stage:   4 Beta: 0.104
# Stage:   5 Beta: 0.281
# Stage:   6 Beta: 0.740
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.010
# Stage:   2 Beta: 0.030
# Stage:   3 Beta: 0.073
# Stage:   4 Beta: 0.177
# Stage:   5 Beta: 0.449
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.032
# Stage:   2 Beta: 0.104
# Stage:   3 Beta: 0.321
# Stage:   4 Beta: 0.973
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.017
# Stage:   2 Beta: 0.048
# Stage:   3 Beta: 0.137
# Stage:   4 Beta: 0.404
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.015
# Stage:   2 Beta: 0.044
# Stage:   3 Beta: 0.130
# Stage:   4 Beta: 0.376
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.025
# Stage:   2 Beta: 0.075
# Stage:   3 Beta: 0.226
# Stage:   4 Beta: 0.577
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.014
# Stage:   3 Beta: 0.035
# Stage:   4 Beta: 0.090
# Stage:   5 Beta: 0.244
# Stage:   6 Beta: 0.615
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.010
# Stage:   2 Beta: 0.028
# Stage:   3 Beta: 0.081
# Stage:   4 Beta: 0.243
# Stage:   5 Beta: 0.716
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.006
# Stage:   1 Beta: 0.025
# Stage:   2 Beta: 0.077
# Stage:   3 Beta: 0.206
# Stage:   4 Beta: 0.508
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.022
# Stage:   2 Beta: 0.067
# Stage:   3 Beta: 0.197
# Stage:   4 Beta: 0.576
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.017
# Stage:   3 Beta: 0.047
# Stage:   4 Beta: 0.136
# Stage:   5 Beta: 0.385
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.001
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.012
# Stage:   3 Beta: 0.029
# Stage:   4 Beta: 0.072
# Stage:   5 Beta: 0.189
# Stage:   6 Beta: 0.512
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.033
# Stage:   2 Beta: 0.265
# Stage:   3 Beta: 1.000
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.013
# Stage:   2 Beta: 0.037
# Stage:   3 Beta: 0.110
# Stage:   4 Beta: 0.323
# Stage:   5 Beta: 0.860
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.022
# Stage:   2 Beta: 0.065
# Stage:   3 Beta: 0.179
# Stage:   4 Beta: 0.492
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.014
# Stage:   3 Beta: 0.042
# Stage:   4 Beta: 0.126
# Stage:   5 Beta: 0.343
# Stage:   6 Beta: 0.844
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.009
# Stage:   2 Beta: 0.028
# Stage:   3 Beta: 0.081
# Stage:   4 Beta: 0.226
# Stage:   5 Beta: 0.578
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.017
# Stage:   2 Beta: 0.048
# Stage:   3 Beta: 0.132
# Stage:   4 Beta: 0.364
# Stage:   5 Beta: 0.998
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.025
# Stage:   2 Beta: 0.075
# Stage:   3 Beta: 0.216
# Stage:   4 Beta: 0.601
# Stage:   5 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.041
# Stage:   2 Beta: 0.242
# Stage:   3 Beta: 0.759
# Stage:   4 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.020
# Stage:   2 Beta: 0.058
# Stage:   3 Beta: 0.138
# Stage:   4 Beta: 0.318
# Stage:   5 Beta: 0.768
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.017
# Stage:   3 Beta: 0.046
# Stage:   4 Beta: 0.111
# Stage:   5 Beta: 0.270
# Stage:   6 Beta: 0.681
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.005
# Stage:   2 Beta: 0.013
# Stage:   3 Beta: 0.039
# Stage:   4 Beta: 0.114
# Stage:   5 Beta: 0.310
# Stage:   6 Beta: 0.768
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.006
# Stage:   1 Beta: 0.023
# Stage:   2 Beta: 0.061
# Stage:   3 Beta: 0.146
# Stage:   4 Beta: 0.363
# Stage:   5 Beta: 0.906
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.032
# Stage:   2 Beta: 0.235
# Stage:   3 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.011
# Stage:   2 Beta: 0.032
# Stage:   3 Beta: 0.094
# Stage:   4 Beta: 0.278
# Stage:   5 Beta: 0.856
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.006
# Stage:   2 Beta: 0.018
# Stage:   3 Beta: 0.045
# Stage:   4 Beta: 0.112
# Stage:   5 Beta: 0.295
# Stage:   6 Beta: 0.745
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.002
# Stage:   1 Beta: 0.007
# Stage:   2 Beta: 0.022
# Stage:   3 Beta: 0.065
# Stage:   4 Beta: 0.158
# Stage:   5 Beta: 0.388
# Stage:   6 Beta: 0.978
# Stage:   7 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.003
# Stage:   1 Beta: 0.010
# Stage:   2 Beta: 0.028
# Stage:   3 Beta: 0.067
# Stage:   4 Beta: 0.163
# Stage:   5 Beta: 0.414
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.013
# Stage:   2 Beta: 0.037
# Stage:   3 Beta: 0.111
# Stage:   4 Beta: 0.337
# Stage:   5 Beta: 0.868
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.004
# Stage:   1 Beta: 0.015
# Stage:   2 Beta: 0.040
# Stage:   3 Beta: 0.098
# Stage:   4 Beta: 0.243
# Stage:   5 Beta: 0.613
# Stage:   6 Beta: 1.000
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Stage:   0 Beta: 0.005
# Stage:   1 Beta: 0.045
# Stage:   2 Beta: 0.186
# Stage:   3 Beta: 0.547
# Stage:   4 Beta: 1.000
# --- 30676.97034263611 seconds ---

# %%
print("svgd-fidliety:",statistics)
print("")
print("sms-fidelity:",statistics_sms)

ave_statistics = np.mean(statistics, axis = 0)
ave_statistics_sms= np.mean(statistics_sms, axis = 0)
print("svgd:",ave_statistics)
print("")
print("ave_sms",ave_statistics_sms)
#ave_statistics[0,:]
# Out:
# svgd-fidliety: [[[0.96407786 0.89890838 0.86980922]
#   [0.99969773 0.97466555 0.99691724]
#   [0.99358506 0.99814075 0.99966761]]
#
#  [[0.98415257 0.99252022 0.88101124]
#   [0.99223143 0.99650879 0.98477805]
#   [0.99922927 0.99094311 0.99557565]]
#
#  [[0.97193285 0.93317699 0.82004605]
#   [0.99316469 0.99327734 0.99146245]
#   [0.99994981 0.99976128 0.99370183]]
#
#  [[0.86047765 0.93257503 0.95629018]
#   [0.9959519  0.98697874 0.98730522]
#   [0.9997663  0.99126818 0.99965898]]
#
#  [[0.96414482 0.97161532 0.88284613]
#   [0.96080489 0.96971687 0.98656554]
#   [0.99113771 0.99948496 0.9996849 ]]
#
#  [[0.9856948  0.93814229 0.98580767]
#   [0.99392958 0.98394336 0.99896364]
#   [0.99955147 0.99978682 0.99991875]]
#
#  [[0.99689327 0.83647191 0.9287955 ]
#   [0.99986108 0.9962507  0.98574671]
#   [0.97512353 0.98234211 0.99979823]]
#
#  [[0.97747049 0.95991336 0.94802901]
#   [0.99780799 0.9992904  0.97718435]
#   [0.98933767 0.97323474 0.98849089]]
#
#  [[0.94605802 0.98977809 0.94485209]
#   [0.98156374 0.9844267  0.9809859 ]
#   [0.99877562 0.99996973 0.9991109 ]]
#
#  [[0.99250385 0.96274175 0.94850711]
#   [0.98026536 0.99314968 0.99350939]
#   [0.99868901 0.99977004 0.99718065]]
#
#  [[0.99810173 0.97134021 0.95544132]
#   [0.99727127 0.99328283 0.98081468]
#   [0.99721813 0.99636266 0.9974531 ]]
#
#  [[0.98493935 0.96196101 0.92095048]
#   [0.9918338  0.99527354 0.9801462 ]
#   [0.9994555  0.97492195 0.99817978]]
#
#  [[0.93518205 0.95091487 0.97662352]
#   [0.99317414 0.99627741 0.99238677]
#   [0.99491284 0.99528313 0.98046155]]
#
#  [[0.93812729 0.89676546 0.95971867]
#   [0.99044252 0.99391711 0.99532927]
#   [0.99887685 0.99537411 0.99438106]]
#
#  [[0.97829738 0.96383568 0.8975617 ]
#   [0.97701106 0.99826772 0.98323822]
#   [0.99321166 0.99563664 0.99928072]]
#
#
#  [[0.91716275 0.84938016 0.95810328]
#   [0.99135166 0.99065583 0.99644275]
#   [0.99586908 0.99940655 0.99893905]]
#
#  [[0.92535835 0.93653649 0.98878847]
#   [0.99881998 0.99787851 0.98639543]
#   [0.99994254 0.99931606 0.99973503]]
#
#  [[0.9842752  0.96765706 0.96655656]
#   [0.98038827 0.98618623 0.98975828]
#   [0.99877911 0.99930044 0.9995468 ]]
#
#  [[0.94963903 0.98171434 0.87217955]
#   [0.99809113 0.99635996 0.98670072]
#   [0.99935282 0.99930588 0.99766893]]
#
#  [[0.97238545 0.99148857 0.92982298]
#   [0.99177366 0.984974   0.9952995 ]
#   [0.99912191 0.99894176 0.99996586]]
#
#  [[0.89687407 0.97906012 0.87825051]
#   [0.99126159 0.99149149 0.99310692]
#   [0.99844963 0.99670431 0.99189127]]
#
#  [[0.87377311 0.98624226 0.96811577]
#   [0.97316854 0.9920823  0.98003313]
#   [0.99323767 0.99821545 0.99957356]]
#
#  [[0.97363682 0.96915654 0.9628557 ]
#   [0.98660287 0.99358812 0.99928169]
#   [0.99933085 0.99954955 0.99959576]]
#
#  [[0.96375705 0.87737422 0.9729717 ]
#   [0.99921821 0.99253146 0.98524469]
#   [0.99725044 0.99885593 0.9936383 ]]
#
#  [[0.98196793 0.84144859 0.9643399 ]
#   [0.98698446 0.9991231  0.98189308]
#   [0.99849762 0.99933469 0.99981999]]
#
#  [[0.96237891 0.93985506 0.97849188]
#   [0.99462903 0.99603489 0.99506553]
#   [0.99774331 0.99909544 0.99964243]]
#
#  [[0.97088836 0.96935035 0.96685934]
#   [0.99079485 0.99793162 0.99919318]
#   [0.99365276 0.99915875 0.99907467]]
#
#  [[0.93326815 0.90800646 0.87536129]
#   [0.98533087 0.99309252 0.9955035 ]
#   [0.99971598 0.99900593 0.99971483]]
#
#  [[0.93702713 0.98095306 0.90536685]
#   [0.99538181 0.99951679 0.99259955]
#   [0.99960425 0.99974505 0.99852048]]
#
#  [[0.87925034 0.88632105 0.90147432]
#   [0.99545963 0.99379499 0.99592514]
#   [0.99951227 0.9960371  0.99520997]]]
# svgd: [[0.95844272 0.93794638 0.94235683]
#  [0.98716318 0.98984865 0.99049889]
#  [0.99279758 0.99220494 0.99388597]]
#
# ave_sms [[0.95081538 0.93699307 0.94261471]
#  [0.99014904 0.99188994 0.99237528]
#  [0.99853343 0.99866449 0.99855116]]

# %%
plt.rcParams["figure.figsize"] = 8, 5
plt.plot(N, ave_statistics[:,0], label = str(particle_num[0])+" particles-SVGD")
plt.plot(N, ave_statistics[:,1], label = str(particle_num[1])+" particles-SVGD")
plt.plot(N, ave_statistics[:,2], label = str(particle_num[2])+" particles-SVGD")

#plt.plot(N, ave_statistics_sms[:,0], label = str(particle_num[0])+" particles-SMS")
#plt.plot(N, ave_statistics_sms[:,1], label = str(particle_num[1])+" particles-SMS")
#plt.plot(N, ave_statistics_sms[:,2], label = str(particle_num[2])+" particles-SMS")
plt.legend(fontsize=10,loc=0)
plt.ylabel("Average Fidelity")
plt.xlabel("Number of particles")
plt.grid()

# %%
plt.plot(N, ave_statistics[0,:], label = str(N[0])+" measurements-SVGD")
plt.plot(N, ave_statistics[1,:], label = str(N[1])+" measurements-SVGD")
plt.plot(N, ave_statistics[2,:], label = str(N[2])+" measurements-SVGD")

plt.plot(N, ave_statistics_sms[0,:], label = str(N[0])+" measurements-SMS")
plt.plot(N, ave_statistics_sms[1,:], label = str(N[1])+" measurements-SMS")
plt.plot(N, ave_statistics_sms[2,:], label = str(N[2])+" measurements-SMS")
plt.legend(fontsize=10,loc=0)
plt.ylabel("Average Fidelity")
plt.xlabel("Number of measurements")
plt.grid()

# %%
ave_statistics
# Out:
# array([[0.95844272, 0.93794638, 0.94235683],
#        [0.98716318, 0.98984865, 0.99049889],
#        [0.99279758, 0.99220494, 0.99388597]])

# %%
ave_statistics_sms
# Out:
# array([[0.95081538, 0.93699307, 0.94261471],
#        [0.99014904, 0.99188994, 0.99237528],
#        [0.99853343, 0.99866449, 0.99855116]])

# %%
N = np.array([10,100,1000])  ## number of measurements 

particle_num = np.array([10,100,1000]) ## number of particles in SVGD

ave_statistics=np.array([[0.95844272, 0.93794638, 0.94235683],
       [0.98716318, 0.98984865, 0.99049889],
       [0.99279758, 0.99220494, 0.99388597]])

# %%
ave_statistics_sms=np.array([[0.95081538, 0.93699307, 0.94261471],
       [0.99014904, 0.99188994, 0.99237528],
       [0.99853343, 0.99866449, 0.99855116]])
final_smc=np.mean(ave_statistics_sms,axis=1)
final_smc
# Out:
# array([0.94347439, 0.99147142, 0.99858303])

# %%
## this cell is to have nice plots
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
plt.rcParams["figure.figsize"] = 10, 7
plt.plot(N, ave_statistics[:,0], label = str(particle_num[0])+" particles-SVGD")
plt.plot(N, ave_statistics[:,1], label = str(particle_num[1])+" particles-SVGD")
plt.plot(N, ave_statistics[:,2], label = str(particle_num[2])+" particles-SVGD")

plt.plot(N, final_smc, label = "SMC")
#plt.plot(N, ave_statistics_sms[:,1], label = "SMC and SVGD uses "+str(particle_num[1])+" part.")
#plt.plot(N, ave_statistics_sms[:,2], label = "SMC and SVGD uses "+str(particle_num[2])+" part.")
plt.legend(fontsize=10,loc=0)
plt.ylabel("Average Fidelity",fontsize=16)
plt.xlabel("Number of measurements",fontsize=16)
plt.title("SVGD using adam vs SMC: Average Fidelity vs $N$",fontsize=16)
plt.legend(fontsize=13)
plt.grid()
plt.savefig('svgd-adam-measurements.png')

# %%
plt.plot(particle_num, ave_statistics[0,:], label = str(N[0])+" measurements-SVGD")
plt.plot(particle_num, ave_statistics[1,:], label = str(N[1])+" measurements-SVGD")
plt.plot(particle_num, ave_statistics[2,:], label = str(N[2])+" measurements-SVGD")

#plt.plot(particle_num, ave_statistics_sms[0,:], label = str(N[0])+" measurements-SMC")
#plt.plot(particle_num, ave_statistics_sms[1,:], label = str(N[1])+" measurements-SMC")
#plt.plot(particle_num, ave_statistics_sms[2,:], label = str(N[2])+" measurements-SMC")
plt.legend(fontsize=10,loc=0)
plt.ylabel("Average Fidelity",fontsize=16)
plt.xlabel("Number of particles",fontsize=16)
plt.title("Aver. fidelity vs num. particles :using adam ",fontsize=16)
plt.legend(fontsize=11)
plt.grid()
plt.savefig('svgd-adam-particles.png')

# %%
print(f"Running on PyMC3 v{pm.__version__}")

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
